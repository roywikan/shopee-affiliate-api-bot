# %%
from datetime import datetime, timedelta
from shopee_affiliate import ShopeeAffiliate

# fresma
appid = "11329420170" # Your appid
secret = "7IR5CEE2UZXUIEB7SLFR5E6CDYVSV5XT" # Your secret

# Ayah
# appid = "11368430183" # Your appid
# secret = "QFIZOMN6JRAY5JJIHXRMPVZLTKN7B5QU" # Your secret

# Ilham
appid = "11332250177" # Your appid
secret = "A2XJFF3A4SZ5DOBQG4RHEKF2SFAHXKAT" # Your secret

# report yesterday
startdate = datetime.now() - timedelta(days=26)
enddate = datetime.now() - timedelta(days=1)

sa = ShopeeAffiliate(appid, secret)
res = sa.report(startdate, enddate)
conversion, estimation, startdate_, enddate_ = res
print("Komisi Tanngal: {} sampai {}".format(startdate_, enddate_))
print("Jumlah Pesanan:", conversion)
print("Estimasi Pendapatan:", estimation)
# Out:
# Komisi Tanngal: 2022-11-06 sampai 2022-12-01
# Jumlah Pesanan: 5
# Estimasi Pendapatan: 22,498

# %%
import mysql.connector
from mysql.connector import Error

try:
    connection = mysql.connector.connect(host='localhost',
                                         database='shopee_aff',
                                         user='root',
                                         password='')
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed")
# Out:
# Connected to MySQL Server version  8.0.30
# You're connected to database:  ('shopee_aff',)
# MySQL connection is closed

# %%
import pandas as pd

iddatabaseThread="1d_feknqrjaa8WmMs3hKwRrm7E7bH2SndRrL212kujAU"

db = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{iddatabaseThread}/export?format=csv")

db
# Out:
#                                            product_name  \
# 0             Erigo Coach Jacket Art Of Peace Dark Grey
# 1                        Erigo Short Shirt Jazlyn Black
# 2                    Erigo T-Shirt Project Summer Black
# 3     Freestyle Jaket Pria Waterproof Anti Air Tasla...
# 4                        Erigo Chino Pants Caprio Brown
# ...                                                 ...
# 2095              Bata Sandal Pria Slav Brown - 8714178
# 2096  Osgood - Sandal Traveling Pria Wanita - Castil...
# 2097  Fladeo F20/MDS227-1AH/Sandal Jepit Pria [ Flip...
# 2098  [9.9 SALE] TVF Footwear - Sandals - Rainier V2...
# 2099  Ando Official Sandal Jepit Hawaii Pria Dewasa ...
#
#               product_price product_rating  \
# 0                 Rp153.000            69%
# 1                  Rp99.000            72%
# 2                  Rp69.000            72%
# 3     Rp130.000 - Rp175.000             3%
# 4                 Rp153.000            66%
# ...

# %%
# Insert

import mysql.connector


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="shopeeaff"
)

mycursor = mydb.cursor()

for i in range(len(db)):
      sql = "INSERT INTO database_post (product_name, product_price, product_rating, product_link, product_img) VALUES (%s, %s, %s, %s, %s)"
      val = (db.iloc[i,0], db.iloc[i,1], db.iloc[i,2], db.iloc[i,3], db.iloc[i,4])
      mycursor.execute(sql, val)

      mydb.commit()

      print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# ...

# %%
# Read
id=2
mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post where no = '%s';" % id)

myresult = mycursor.fetchall()

for x in myresult:
  print(x[4])
# Out:
# https://cf.shopee.co.id/file/baf827394f05c1899c5b0cf00f6e273f

# %%
import pandas as pd

userID = "spongebobnfess"

idDataBaseItem = '15JVk3QaMzRIzvXGq8KNgUO4i6RFyG12h0BXUKlrFf2Q'

idAccountEleved = '1rrMfA_cJl8CYtkotUWTCc5YrDdPwMGOYM6gjcWG1Zoc'

idAccountNonEleved = '12j2_55r-fwcPI4hAzuHQZhKv_W5DXZXkclljm2galyo'

idAccountTest = '1NMn4n-5W67EIiqPd7izLWFvlzRPMgcBAdXSmRbUHIyU'

iddatabaseThread = '1cyNu0v-4x045vcJs_qIvJGnsSX28SVL--4zu8qIcnYo'

db = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{idDataBaseItem}/export?format=csv")

acEleved = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{idAccountEleved}/export?format=csv")

acNonEleved = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{idAccountNonEleved }/export?format=csv")

acTest = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{idAccountTest}/export?format=csv")

acdbThread = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{iddatabaseThread}/export?format=csv")

acNonEleved
# Out:
#           Username                    API_KEY  \
# 0   SaraAlamilla11  PfnTaj1jeRmeiA96wHhYILqG7
# 1     putridewia_a  XF4ufyxNn3SmuuyEqCTkh0Jne
# 2  nirmalsalsabila  BmzHkAmV2waRuphJcBCaSD53W
# 3   ArianaAbascal1  WB1fVfq6CxZbtWARADCI6nqlw
# 4     vaniakeisya_  q3geGxYCieCDGKQv5PAGiVekg
# 5   samaira_nafisa  n1lXXmMM9Vo5GJqi8fhu0i6jX
# 6   SimonJuarez282  lIGsm96mCjMeTCF61FSrxx2Sq
# 7   posyvidya77996  fQrVx2t0MVViTCgV3cM3BUbba
# 8     _firzaamanda  qwmLnf5CTSiTN5kKGWuOuZQY7
# 9      yusiedaynti  yz9zFRh2o8J9uj7kG8OLm33F6
#
#                                       API_SECRET_KEY  \
# 0  kYKEqNWVnZvg37PEK65O5dng4KDL0SbuWBVg3Kll8HEZN6...
# 1  O0gnnXOr53Rvxr4DaRGaknPux6TGRxPw9ZzMdz2Uyq3jwR...
# 2  5kUGBmYqwbAMOLChKfzFcSP7vs3XW8oxZi99EwbSIt0EyN...
# 3  rTt4fy2N3KVlG0c8MKIKdec7pXkOzNoh1Y2G0RNTv345ep...
# 4  vCwe9Pfs9euwnbzW6AfmMK1s2vOe3t4z07ff8QQqP2Kdw9...
# 5  SGBiEuimb1uNpOZMP1oAmmfZGtSOFcNJanEvn8ewP4gN4K...
# 6  pl2c4IBRSaKPVn7BUU823NpKqKIw3gLI9vpqAm3jNVU632...
# ...

# %%
acdbThread.iloc[0,1]
# Out:
# 1551394491881336833

# %%
import mysql.connector


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="shopeeaff"
)

mycursor = mydb.cursor()

for i in range(len(acNonEleved)):
      sql = "INSERT INTO account_non_eleved (username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN) VALUES (%s, %s, %s, %s, %s, %s)"
      val = (acNonEleved.iloc[i,0], acNonEleved.iloc[i,1], acNonEleved.iloc[i,2], acNonEleved.iloc[i,3], acNonEleved.iloc[i,4], acNonEleved.iloc[i,5])
      mycursor.execute(sql, val)

      mydb.commit()

      print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.

# %%
import mysql.connector


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="shopeeaff"
)

mycursor = mydb.cursor()

for i in range(len(acdbThread)):  
      sql = "INSERT INTO database_thread (keterangan, no) VALUES (%s, %s)"
      val = (acdbThread.iloc[1,0], acdbThread.iloc[i,1])
      mycursor.execute(sql, val)

      mydb.commit()

      print(mycursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# d:\Bot\Bot Aff Shopee\affshopee.ipynb Cell 9 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/affshopee.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> sql = "INSERT INTO database_thread (keterangan, no) VALUES (%s, %s)"
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/affshopee.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a> val = (acdbThread.iloc[1,0], acdbThread.iloc[i,1])
# ---> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/affshopee.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a> mycursor.execute(sql, val)
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/affshopee.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a> mydb.commit()
# ...
