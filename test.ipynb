# %%
from distutils.log import info
from itertools import count
import tweepy as twitter
import time
from datetime import datetime
import pandas as pd
import random
import urllib.request
from PIL import Image
import requests
import schedule
from py3pin.Pinterest import Pinterest
import mysql.connector


# Login Pinters
pinterest = Pinterest(email='fresmaazz@gmail.com',
                      password='Azzukhruf26',
                      username='id_myfashion',
                      cred_root='cred_root')


# Database
userID = "spongebobnfess"

idDataBaseItem = '15JVk3QaMzRIzvXGq8KNgUO4i6RFyG12h0BXUKlrFf2Q'

iddatabaseThread = '1cyNu0v-4x045vcJs_qIvJGnsSX28SVL--4zu8qIcnYo'

acdbThread = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{iddatabaseThread}/export?format=csv")

db = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{idDataBaseItem}/export?format=csv")



# Connect Database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="shopee_aff"
)

# %%
def botTwitter():
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"
    
    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)
    
    return API

def main():
    
    tweets = botTwitter().user_timeline(screen_name=userID, count=1, tweet_mode='extended')
    print(tweets)
    
    
main()
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000026B5DAEEBB0>, _json={'created_at': 'Sat Dec 03 07:47:03 +0000 2022', 'id': 1598946904905089024, 'id_str': '1598946904905089024', 'full_text': 'SS! buat yg suka jbjb mutualan ayo rt aja 🐹', 'truncated': False, 'display_text_range': [0, 43], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cheapbotsdonequick.com" rel="nofollow">Cheap Bots, Done Quick!</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1409911410084229128, 'id_str': '1409911410084229128', 'name': 'BASE FOR MUTUALAN - USE SS!', 'screen_name': 'spongebobnfess', 'location': '', 'description': 'kami kembali lagi 💪', 'url': 'https://t.co/trZ1oAohMU', 'entities': {'url': {'urls': [{'url': 'https://t.co/trZ1oAohMU', 'expanded_url': 'https://twitter.com/search/from:@AlMosahf$-filter:mentions', 'display_url': 'twitter.com/search/from:@A…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 74729, 'friends_count': 0, 'listed_count': 450, 'created_at': 'Tue Jun 29 16:27:46 +0000 2021', 'favourites_count': 34, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 29123, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1558717400773697536/iqn8OsA-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1558717400773697536/iqn8OsA-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1409911410084229128/1660462162', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 40, 'favorite_count': 5, 'favorited': False, 'retweeted': False, 'lang': 'in'}, created_at=datetime.datetime(2022, 12, 3, 7, 47, 3, tzinfo=datetime.timezone.utc), id=1598946904905089024, id_str='1598946904905089024', full_text='SS! buat yg suka jbjb mutualan ayo rt aja 🐹', truncated=False, display_text_range=[0, 43], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Cheap Bots, Done Quick!', source_url='https://cheapbotsdonequick.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000026B5DAEEBB0>, _json={'id': 1409911410084229128, 'id_str': '1409911410084229128', 'name': 'BASE FOR MUTUALAN - USE SS!', 'screen_name': 'spongebobnfess', 'location': '', 'description': 'kami kembali lagi 💪', 'url': 'https://t.co/trZ1oAohMU', 'entities': {'url': {'urls': [{'url': 'https://t.co/trZ1oAohMU', 'expanded_url': 'https://twitter.com/search/from:@AlMosahf$-filter:mentions', 'display_url': 'twitter.com/search/from:@A…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 74729, 'friends_count': 0, 'listed_count': 450, 'created_at': 'Tue Jun 29 16:27:46 +0000 2021', 'favourites_count': 34, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 29123, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_backg ...

# %%
mycursor = mydb.cursor(dictionary=True)

# mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_non_eleved WHERE username <> 'yusiedaynti' AND username <> '_firzaamanda' AND username <> 'vidyaisvara' AND username <> 'zannakirana_' ")

mycursor = mydb.cursor(dictionary=True)
mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id=1")
account_shopee = mycursor.fetchall()



print(account_shopee[0]['rahasia'])
# Out:
# 7IR5CEE2UZXUIEB7SLFR5E6CDYVSV5XT

# %%
API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
API = twitter.API(auth)
   
tweets = API.user_timeline(screen_name=userID,
                                   # 200 is the maximum allowed count
                                   count=1,
                                   # Necessary to keep full_text
                                   # otherwise only the first 140 words are extracted
                                   tweet_mode='extended'
                                   )
for info in tweets[:1]:
            print("ID : {}".format(info.id))

mycursor = mydb.cursor()

mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup WHERE id_shopee=1 AND username='sarhagthang' AND username='Donni_darwin'")

accountResult = mycursor.fetchall()

for i in range(len(accountResult)):
        auth = twitter.OAuth1UserHandler(
            "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
            accountResult[i][3], accountResult[i][4]
        )
        api = twitter.API(auth)

        print("Account : {}".format(accountResult[i][2]))

        for info in tweets[:1]:
            print("ID : {}".format(info.id))

        try:
            api.retweet(id=info.id)
            print("✅ - Retweet Berhasil\n")
        except twitter.TweepyException as e:
            print(e)
            pass
# Out:
# ID : 1580480213166669829

# %%
def autorepostAkunAyah() :
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)
    userIDaccount = "masitowae"

    tweets = API.user_timeline(screen_name=userIDaccount,
                                   # 200 is the maximum allowed count
                                   count=200,
                                   include_rts=False,
                                   # Necessary to keep full_text
                                   # otherwise only the first 140 words are extracted
                                   tweet_mode='extended'
                                   )

    mycursor = mydb.cursor()

    mycursor.execute("SELECT id_shopee, no, id, username, access_token, access_token_secret FROM account_backup WHERE id_shopee=2 ORDER BY no DESC")

    accountResult = mycursor.fetchall()

    for x in range(1):
        auth = twitter.OAuth1UserHandler(
            "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
            accountResult[x][4], accountResult[x][5]
        )
        api = twitter.API(auth)

        print("Account : {}".format(accountResult[x][3]))

        totalA = 2
        for index in range(len(tweets)-1, 0, -1):
                if totalA != 0:
                    try :
                        random_index = random.randrange(len(tweets))
                        api.unretweet(id =tweets[random_index].id)
                        api.retweet(id=tweets[random_index].id)
                        print("✅ - Repost Berhasil")
                        totalA = totalA - 1
                    except twitter.TweepyException as e:
                        pass
                        print(e)
                else:
                    break

autorepostAkunAyah()
# Out:
# Account : imamto2003
# ✅ - Repost Berhasil
# ✅ - Repost Berhasil
# Account : masitowae
# ✅ - Repost Berhasil
# ✅ - Repost Berhasil

# %%
import tweepy as twitter

API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
API = twitter.API(auth)

API.get_user(screen_name="HappyRacun")

# apc = twitter.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAANiYhgEAAAAAPoytdCCP3%2BiBsRGh7oGpdfoM%2B14%3DYOQq0OAutl2ZdL0RdsnR6s7EQn7SSXdoMqIZZkF3rneaMqg2Pz", consumer_key="IwDEKnMpeDfiR6gh0Smx2Oa3J", consumer_secret="YOgmrbsHfWN9rIp2r0aXB1284U5QR2HGSeGrOaBq78KhqMJtA0", access_token="1524280323739389952-8oMZlcHMHHbF4wXIj2qTmVmPEgcigi", access_token_secret="ewYWVWvHzJwAdTokc6ShmGx5xBtAjAU2xrHjEgJMTeAPU")
        
# statusTweet = "‼ FLASH SALE ‼\n\n\n\n⛔️ DISKON : \n\nCheckout Sekarang 👇\n"

# media = API.media_upload("imagePost.png", additional_owners=["1524280323739389952"])
# media_ids = [media.media_id]

# apc.create_tweet(text=statusTweet, media_ids=media_ids)
# Out:
# User(_api=<tweepy.api.API object at 0x0000021AFC0A73A0>, _json={'id': 1585458215986548737, 'id_str': '1585458215986548737', 'name': 'Racun Shopee Happy', 'screen_name': 'HappyRacun', 'location': 'Indonesia', 'profile_location': None, 'description': 'Dapatkan rekomendasi produk-produk diskon Shopee', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Thu Oct 27 02:27:58 +0000 2022', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5, 'lang': None, 'status': {'created_at': 'Thu Oct 27 02:36:10 +0000 2022', 'id': 1585460314346487808, 'id_str': '1585460314346487808', 'text': 'RT @spongebobnfess: SS! mutualan gais rt aja yg ga fb gosah rt 🌓', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'spongebobnfess', 'name': 'BASE FOR MUTUALAN - USE SS!', 'id': 1409911410084229128, 'id_str': '1409911410084229128', 'indices': [3, 18]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Oct 27 01:56:57 +0000 2022', 'id': 1585450448059654144, 'id_str': '1585450448059654144', 'text': 'SS! mutualan gais rt aja yg ga fb gosah rt 🌓', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cheapbotsdonequick.com" rel="nofollow">Cheap Bots, Done Quick!</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 99, 'favorite_count': 18, 'favorited': False, 'retweeted': False, 'lang': 'in'}, 'is_quote_status': False, 'retweet_count': 99, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'in'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1585459921612857345/NYwSITTJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1585459921612857345/NYwSITTJ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1585458215986548737/1666838076', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=1585458215986548737, id_str='1585458215986548737', name='Racun Shopee Happy', screen_name='HappyRacun', location='Indonesia', profile_location=None, description='Dapatkan rekomendasi produk-produk diskon Shopee', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=1, friends_count=2, listed_count=0, created_at=datetime.datetime(2022, 10, 27, 2, 27, 58, tzinfo=datetime.timezone.utc), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=5, lang=None, status=Status(_api=<tweepy.api.API object at 0x0000021AFC0A73A0>, _json={'created_at': 'Thu Oct 27 02:36:10 +0000 2022', 'id': 1585460314346487808, 'id_str': '1585460314346487808', 'text': 'RT @spongebobnfess: SS! mutualan gais rt aja yg ga fb gosah rt 🌓', 'truncated': Fal ...

# %%
import tweepy

def autopostingAkunBackUp():
       
   API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
   API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
   BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
   ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
   SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

   auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
   auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
   API = twitter.API(auth)

   mycursor = mydb.cursor()

   mycursor.execute("SELECT id,username, access_token, access_token_secret FROM account_backup WHERE ")

   accountResult = mycursor.fetchall()

   mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

   database_post = mycursor.fetchall()

   print(accountResult)

   for i in range(len(accountResult)):
          
      random_index = random.randrange(len(database_post))

      urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
          
      media = API.media_upload("imagePost.png", additional_owners=[accountResult[i][0]])

      auth = tweepy.OAuth1UserHandler(
         "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
         accountResult[i][2], accountResult[i][3]
      )
      api = tweepy.API(auth)

      statusTweet = "‼ FLASH SALE ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3]))

      api.update_status(status=statusTweet, media_ids=[media.media_id])

def shortLinkShopee(link):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT appid, rahasia FROM account_shopeeaff")
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][0], account_shopee[0][1])
    res = sa.generateShortLink(link)
    res = res.replace("shope", "shpe")
    return res

autopostingAkunBackUp()
# Out:
# [('2235103213', 'yusiedaynti', '2235103213-ynz7SUeFnKn45r4quVONZLamdbL1uWmkk9R2c7s', 'NikHfyiJfNW7AFmVKt3rwo6YduJZuLN7jKZxfzi1xsu58'), ('1533162697', '_firzaamanda', '1533162697-svdfTiJb2hb65jgqnY7iagr7c98lczLITEpj6Rq', 'a8lQsA4hXsFnKF5khvvk52JIiGYEDMe36E1kcaZn1s0rX')]

# %%
def autorepostAkunBackup():
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)
   
    tweets = API.user_timeline(screen_name=userID,
                                   # 200 is the maximum allowed count
                                   count=1,
                                   # Necessary to keep full_text
                                   # otherwise only the first 140 words are extracted
                                   tweet_mode='extended'
                                   )

    mycursor = mydb.cursor()

    mycursor.execute("SELECT id,username, access_token, access_token_secret FROM account_backup")

    accountResult = mycursor.fetchall()
    
    for i in range(len(accountResult)):
        auth = tweepy.OAuth1UserHandler(
            "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
            accountResult[i][2], accountResult[i][3]
        )
        api = tweepy.API(auth)

        for info in tweets[:1]:
            print("ID : {}".format(info.id))

        try:
            api.retweet(id=info.id)
            print("✅ - Retweet Berhasil\n")
        except twitter.TweepyException as e:
            print(e)
            pass

autorepostAkunBackup()
# Out:
# ID : 1576383168810082305
# 403 Forbidden
# 327 - You have already retweeted this Tweet.
# ID : 1576383168810082305
# 403 Forbidden
# 327 - You have already retweeted this Tweet.

# %%
def autorepostNonEleved() :
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)
    # random_index_id = random.randrange(len(acEleved))
    userIDaccount = "id_myfashion"

    tweets = API.user_timeline(screen_name=userIDaccount,
                                   # 200 is the maximum allowed count
                                   count=200,
                                   include_rts=False,
                                   # Necessary to keep full_text
                                   # otherwise only the first 140 words are extracted
                                   tweet_mode='extended'
                                   )

    mycursor = mydb.cursor()

    mycursor.execute("SELECT id,username, access_token, access_token_secret FROM account_backup")

    accountResult = mycursor.fetchall()

    for x in range(8):
        auth = twitter.OAuth1UserHandler(
            "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
            accountResult[x][2], accountResult[x][3]
        )
        api = twitter.API(auth)

        print("Account : {}".format(accountResult[x][1]))

        totalA = 3
        for index in range(len(tweets)-1, 0, -1):
                if totalA != 0:
                    try :
                        random_index = random.randrange(len(tweets))
                        api.unretweet(id =tweets[random_index].id)
                        api.retweet(id=tweets[random_index].id)
                        print("✅ - Repost Berhasil")
                        api.create_favorite(id=tweets[random_index].id)
                        totalA = totalA - 1
                    except twitter.TweepyException as e:
                        pass
                        print(e)
                else:
                    break

autorepostNonEleved()
# Out:
# Account : yusiedaynti
# ✅ - Repost Berhasil
# ✅ - Repost Berhasil
# ✅ - Repost Berhasil
# Account : _firzaamanda
# ✅ - Repost Berhasil
# ✅ - Repost Berhasil
# ✅ - Repost Berhasil
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 5 in <cell line: 54>()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=50'>51</a>                 else:
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=51'>52</a>                     break
# ---> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=53'>54</a> autorepostNonEleved()
#
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 5 in autorepostNonEleved()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a> accountResult = mycursor.fetchall()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=28'>29</a> for x in range(8):
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=29'>30</a>     auth = twitter.OAuth1UserHandler(
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=30'>31</a>         "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
# ---> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=31'>32</a>         accountResult[x][2], accountResult[x][3]
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=32'>33</a>     )
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=33'>34</a>     api = twitter.API(auth)
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X20sZmlsZQ%3D%3D?line=35'>36</a>     print("Account : {}".format(accountResult[x][1]))
#
# IndexError: list index out of range

# %%
# auto posting
def autoposting():
    print("\n\n🟧 AUTO POSTING : {}\n".format(datetime.now()))

    mycursor = mydb.cursor()

    mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_eleved")

    accountResult = mycursor.fetchall()

    mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

    database_post = mycursor.fetchall()

    for x in range(len(accountResult)):
        auth = twitter.OAuthHandler(accountResult[x][1], accountResult[x][2])
        auth.set_access_token(accountResult[x][4], accountResult[x][5])
        api = twitter.API(auth)

        profile = api.update_profile()

        print("\nAccount : {}".format(profile.name) + " ({})".format(profile.screen_name))

        random_index = random.randrange(len(database_post))

        # upload image
        urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
        
        statusTweet = "‼ FLASH SALE ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3]))
        # media = api.media_upload("imagePost.png")
        media = api.media_upload("imagePost.png", chunked=True, media_category="tweet_video")
        media_ids = [media.media_id]

       
        # asfasfasf
        # media = api.media_upload("imagePost.png", chunked=True, media_category="tweet_video")
        media_ids = [media.media_id]  # It can be a list of integers
        apc = twitter.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAANiYhgEAAAAAPoytdCCP3%2BiBsRGh7oGpdfoM%2B14%3DYOQq0OAutl2ZdL0RdsnR6s7EQn7SSXdoMqIZZkF3rneaMqg2Pz", consumer_key="IwDEKnMpeDfiR6gh0Smx2Oa3J", consumer_secret="YOgmrbsHfWN9rIp2r0aXB1284U5QR2HGSeGrOaBq78KhqMJtA0", access_token="1524280323739389952-8oMZlcHMHHbF4wXIj2qTmVmPEgcigi", access_token_secret="ewYWVWvHzJwAdTokc6ShmGx5xBtAjAU2xrHjEgJMTeAPU")

        apc.create_tweet(text=statusTweet, media_ids=media_ids)
        # api.update_status(status=statusTweet, media_ids=[media.media_id])

        # Post Telegram
        message = 'https://api.telegram.org/bot5479078966:AAECnT7JEy4hNpjHGUzdZtSTsgOOjN22O_8/sendPhoto?chat_id=-1001658353827&photo={}&caption={}'.format(database_post[random_index][4], statusTweet)
        requests.post(message)

def shortLinkShopee(link):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT appid, rahasia FROM account_shopeeaff")
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][0], account_shopee[0][1])
    res = sa.generateShortLink(link)
    # res = res.replace("shope", "shpe")
    print(res)
    

autoposting()
# Out:
# 🟧 AUTO POSTING : 2022-09-30 23:15:02.696240
#
#
# Account : My Fashion Collection✨ (id_myfashion)
# https://shope.ee/5AHJCrfcNF
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 2 in <cell line: 59>()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=54'>55</a>     # res = res.replace("shope", "shpe")
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a>     print(res)
# ---> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=58'>59</a> autoposting()
#
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 2 in autoposting()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=36'>37</a> media_ids = [media.media_id]  # It can be a list of integers
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a> apc = twitter.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAANiYhgEAAAAAPoytdCCP3%2BiBsRGh7oGpdfoM%2B14%3DYOQq0OAutl2ZdL0RdsnR6s7EQn7SSXdoMqIZZkF3rneaMqg2Pz", consumer_key="IwDEKnMpeDfiR6gh0Smx2Oa3J", consumer_secret="YOgmrbsHfWN9rIp2r0aXB1284U5QR2HGSeGrOaBq78KhqMJtA0", access_token="1524280323739389952-8oMZlcHMHHbF4wXIj2qTmVmPEgcigi", access_token_secret="ewYWVWvHzJwAdTokc6ShmGx5xBtAjAU2xrHjEgJMTeAPU")
# ---> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=39'>40</a> apc.create_tweet(text=statusTweet, media_ids=media_ids)
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=40'>41</a> # api.update_status(status=statusTweet, media_ids=[media.media_id])
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=41'>42</a>
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=42'>43</a> # Post Telegram
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#W1sZmlsZQ%3D%3D?line=43'>44</a> message = 'https://api.telegram.org/bot5479078966:AAECnT7JEy4hNpjHGUzdZtSTsgOOjN22O_8/sendPhoto?chat_id=-1001658353827&photo={}&caption={}'.format(database_post[random_index][4], statusTweet)
#
# File c:\Users\muham\anaconda3\envs\me\lib\site-packages\tweepy\client.py:824, in Client.create_tweet(self, direct_message_deep_link, for_super_followers_only, place_id, media_ids, media_tagged_user_ids, poll_duration_minutes, poll_options, quote_tweet_id, exclude_reply_user_ids, in_reply_to_tweet_id, reply_settings, text, user_auth)
#     821 if text is not None:
#     822     json["text"] = text
# --> 824 return self._make_request(
#     825     "POST", f"/2/tweets", json=json, user_auth=user_auth
#     826 )
#
# File c:\Users\muham\anaconda3\envs\me\lib\site-packages\tweepy\client.py:126, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     122 def _make_request(self, method, route, params={}, endpoint_parameters=None,
#     123                   json=None, data_type=None, user_auth=False):
#     124     request_params = self._process_params(params, endpoint_parameters)
# --> 126     response = self.request(method, route, params=request_params,
#     127                             json=json, user_auth=user_auth)
#     129     if self.return_type is requests.Response:
#     130         return response
#
# File c:\Users\muham\anaconda3\envs\me\lib\site-packages\tweepy\client.py:95, in BaseClient.request(self, method, route, params, json, user_auth)
#      87 log.debug(
#      88     "Received API response: "
#      89     f"{response.status_code} {response.reason}\n"
#      90     f"Headers: {response.headers}\n"
#      91     f"Content: {response.content}"
#      92 )
#      94 if response.status_code == 400:
# ---> 95     raise BadRequest(response)
#      96 if response.status_code == 401:
#      97     raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# Your media IDs are invalid.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> print(media)
#
# NameError: name 'media' is not defined

# %%
def autopostingBackup():
    print("\n\n🟧 AUTO POSTING : {}\n".format(datetime.now()))

    mycursor = mydb.cursor()

    mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_eleved")

    accountResult = mycursor.fetchall()

    for x in range(0, 1, 1):
        auth = twitter.OAuthHandler(accountResult[x][1], accountResult[x][2])
        auth.set_access_token(accountResult[x][4], accountResult[x][5])
        api = twitter.API(auth)

        profile = api.update_profile()

        print("\nAccount : {}".format(profile.name) + " ({})".format(profile.screen_name))

        random_index = random.randrange(len(db))

        # upload image
        urllib.request.urlretrieve('{}'.format(db.iloc[random_index, 4]), "imagePost.png")
        
        statusTweet = "‼ FLASH SALE ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(db.iloc[random_index, 0], db.iloc[random_index, 2], db.iloc[random_index, 3])
        media = api.media_upload("imagePost.png")
        api.update_status(status=statusTweet, media_ids=[media.media_id])

        # Post Telegram
        message = 'https://api.telegram.org/bot5479078966:AAECnT7JEy4hNpjHGUzdZtSTsgOOjN22O_8/sendPhoto?chat_id=-1001658353827&photo={}&caption={}'.format(db.iloc[random_index, 4], statusTweet)
        requests.post(message)
        print("✅ - Posting Berhasil\n")

autopostingBackup()
# Out:
# 🟧 AUTO POSTING : 2022-09-28 17:51:20.898678
#
#
# Account : My Fashion Collection✨ (id_myfashion)
# ✅ - Posting Berhasil

# %%
def autoRetweetNonEleved():
    # Minta bantuan akun eleved
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)
   
    tweets = API.user_timeline(screen_name=userID,
                                   # 200 is the maximum allowed count
                                   count=1,
                                   # Necessary to keep full_text
                                   # otherwise only the first 140 words are extracted
                                   tweet_mode='extended'
                                   )

    mycursor = mydb.cursor()

    mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_non_eleved")

    accountResult = mycursor.fetchall()

    for x in range(len(accountResult)):

        api = twitter.Client(bearer_token=accountResult[x][3], consumer_key=accountResult[x][1], consumer_secret=accountResult[x][2], access_token=accountResult[x][4], access_token_secret=accountResult[x][5])
        print("Account : {}".format(accountResult[x][0]))

        for info in tweets[:1]:
            print("ID : {}".format(info.id))

        try:
            api.retweet(tweet_id=info.id)
            print("✅ - Retweet Berhasil\n")
        except twitter.TweepyException as e:
            pass
            print(e)

autoRetweetNonEleved()
# Out:
# Account : SaraAlamilla11
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : putridewia_a
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : nirmalsalsabila
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : ArianaAbascal1
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : vaniakeisya_
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : samaira_nafisa
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : SimonJuarez282
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : posyvidya77996
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : _firzaamanda
# ID : 1575436967159861248
# ✅ - Retweet Berhasil
#
# Account : yusiedaynti
# ID : 1575436967159861248
# ✅ - Retweet Berhasil

# %%
def autorepostNonEleved() :
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    api = twitter.API(auth)
    # random_index_id = random.randrange(len(acEleved))
    userIDaccount = "id_myfashion"

    tweets = api.user_timeline(screen_name=userIDaccount,
                                   # 200 is the maximum allowed count
                                   count=2,
                                   include_rts=False,
                                   # Necessary to keep full_text
                                   # otherwise only the first 140 words are extracted
                                   tweet_mode='extended'
                                   )

    print(tweets)
    # mycursor = mydb.cursor()

    # mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_non_eleved")

    # accountResult = mycursor.fetchall()

    # for x in range(len(accountResult)):
    #     API = twitter.Client(bearer_token=accountResult[x][3], consumer_key=accountResult[x][1], consumer_secret=accountResult[x][2], access_token=accountResult[x][4], access_token_secret=accountResult[x][5])
    #     print("Account : {}".format(accountResult[x][0]))

    #     totalA = 3
    #     for index in range(len(tweets)-1, 0, -1):
    #             if totalA != 0:
    #                 try :
    #                     random_index = random.randrange(len(tweets))
    #                     API.unretweet(source_tweet_id =tweets[random_index].id)
    #                     API.retweet(tweet_id=tweets[random_index].id)
    #                     print("✅ - Repost Berhasil")
    #                     API.like(tweet_id=tweets[random_index].id)
    #                     totalA = totalA - 1
    #                 except twitter.TweepyException as e:
    #                     pass
    #                     print(e)
    #             else:
    #                 break


autorepostNonEleved()
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001D48D0B4190>, _json={'created_at': 'Fri Sep 30 10:40:51 +0000 2022', 'id': 1575797817465266176, 'id_str': '1575797817465266176', 'full_text': '‼ FLASH SALE ‼\n\nJam Tangan Wanita Digital SKMEI 1074 Blue Water Resistant 50m\n\n⛔️ DISKON : 60%\n\nCheckout Sekarang 👇\nhttps://t.co/sRLZCJglL4 https://t.co/1oQCP5Z9Cy', 'truncated': False, 'display_text_range': [0, 139], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/sRLZCJglL4', 'expanded_url': 'https://shpe.ee/8pAbCdupma', 'display_url': 'shpe.ee/8pAbCdupma', 'indices': [116, 139]}], 'media': [{'id': 1575797814533459968, 'id_str': '1575797814533459968', 'indices': [140, 163], 'media_url': 'http://pbs.twimg.com/media/Fd5bw20akAAKHkq.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fd5bw20akAAKHkq.jpg', 'url': 'https://t.co/1oQCP5Z9Cy', 'display_url': 'pic.twitter.com/1oQCP5Z9Cy', 'expanded_url': 'https://twitter.com/id_myfashion/status/1575797817465266176/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 800, 'h': 800, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 800, 'h': 800, 'resize': 'fit'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1575797814533459968, 'id_str': '1575797814533459968', 'indices': [140, 163], 'media_url': 'http://pbs.twimg.com/media/Fd5bw20akAAKHkq.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fd5bw20akAAKHkq.jpg', 'url': 'https://t.co/1oQCP5Z9Cy', 'display_url': 'pic.twitter.com/1oQCP5Z9Cy', 'expanded_url': 'https://twitter.com/id_myfashion/status/1575797817465266176/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 800, 'h': 800, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 800, 'h': 800, 'resize': 'fit'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]}, 'source': '<a href="https://www.facebook.com/" rel="nofollow">RetweetBotKu</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1313965309485670400, 'id_str': '1313965309485670400', 'name': 'My Fashion Collection✨', 'screen_name': 'id_myfashion', 'location': 'Indonesia', 'description': 'Rekomendasi fashion pria dan wanita murah dan menarik ✨ | Cek Chanel Telegram untuk mendapatkan Giveaway dan Promo, klik link di bawah 👇', 'url': 'https://t.co/qkb0soUx9G', 'entities': {'url': {'urls': [{'url': 'https://t.co/qkb0soUx9G', 'expanded_url': 'https://t.me/racun_shpee_murah', 'display_url': 't.me/racun_shpee_mu…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2232, 'friends_count': 1814, 'listed_count': 0, 'created_at': 'Wed Oct 07 22:12:10 +0000 2020', 'favourites_count': 3902, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 11023, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1538703816631066625/wucMqKXa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1538703816631066625/wucMqKXa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1313965309485670400/1654058734', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status':  ...

# %%
def autopostThred():
    mycursor = mydb.cursor()

    mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_non_eleved")

    accountResult = mycursor.fetchall()

    for x in range(len(accountResult)):
        API = twitter.Client(bearer_token=accountResult[x][3], consumer_key=accountResult[x][1], consumer_secret=accountResult[x][2], access_token=accountResult[x][4], access_token_secret=accountResult[x][5])
        print("Account : {}".format(accountResult[x][0]))

        for index in range(0, len(acdbThread), 1):
                    try :
                        API.unretweet(source_tweet_id =acdbThread.iloc[index,1])
                        API.retweet(tweet_id=acdbThread.iloc[index,1])
                        print("✅ - Repost Berhasil - {}".format(acdbThread.iloc[index,1]))
                    except twitter.TweepyException as e:
                        pass
                        print(e)

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_non_eleved")

accountNonEleved = mycursor.fetchall()

mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_eleved")

accountResult = mycursor.fetchall()

mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

database_post = mycursor.fetchall()

mycursor.execute("SELECT appid, rahasia FROM account_shopeeaff")

account_shopee = mycursor.fetchall()

# %%
statusbot = "1nzzMebmvMyODar_9LivVMh7U8UuGwAwUL6kQzSZaAtI"

status = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{statusbot}/export?format=csv")

if(status.iloc[0][0] == "Aktif"):
    print("Status Berjalan")
else :
    print("Mati")
# Out:
# Mati

# %%
import tweepy as twitter

api = twitter.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAANiYhgEAAAAA3QyGvFuYq%2BiUbwXTTtxMo8fhCGM%3DOEc3o15IXSdsjRWU3r7MOo5w289wXZ91wFZfNKZWNrfpACnDyB", consumer_key="IwDEKnMpeDfiR6gh0Smx2Oa3J", consumer_secret="YOgmrbsHfWN9rIp2r0aXB1284U5QR2HGSeGrOaBq78KhqMJtA0", access_token="1524280323739389952-8oMZlcHMHHbF4wXIj2qTmVmPEgcigi", access_token_secret="ewYWVWvHzJwAdTokc6ShmGx5xBtAjAU2xrHjEgJMTeAPU")

id=[1575797814533459968]

api.create_tweet(text='hello world senja', media_ids=id)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 10 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> api = twitter.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAANiYhgEAAAAA3QyGvFuYq%2BiUbwXTTtxMo8fhCGM%3DOEc3o15IXSdsjRWU3r7MOo5w289wXZ91wFZfNKZWNrfpACnDyB", consumer_key="IwDEKnMpeDfiR6gh0Smx2Oa3J", consumer_secret="YOgmrbsHfWN9rIp2r0aXB1284U5QR2HGSeGrOaBq78KhqMJtA0", access_token="1524280323739389952-8oMZlcHMHHbF4wXIj2qTmVmPEgcigi", access_token_secret="ewYWVWvHzJwAdTokc6ShmGx5xBtAjAU2xrHjEgJMTeAPU")
#       <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> id=[1575797814533459968]
# ----> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> api.create_tweet(text='hello world senja', media_ids=id)
#
# File c:\Users\muham\anaconda3\envs\me\lib\site-packages\tweepy\client.py:824, in Client.create_tweet(self, direct_message_deep_link, for_super_followers_only, place_id, media_ids, media_tagged_user_ids, poll_duration_minutes, poll_options, quote_tweet_id, exclude_reply_user_ids, in_reply_to_tweet_id, reply_settings, text, user_auth)
#     821 if text is not None:
#     822     json["text"] = text
# --> 824 return self._make_request(
#     825     "POST", f"/2/tweets", json=json, user_auth=user_auth
#     826 )
#
# File c:\Users\muham\anaconda3\envs\me\lib\site-packages\tweepy\client.py:126, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     122 def _make_request(self, method, route, params={}, endpoint_parameters=None,
#     123                   json=None, data_type=None, user_auth=False):
#     124     request_params = self._process_params(params, endpoint_parameters)
# --> 126     response = self.request(method, route, params=request_params,
#     127                             json=json, user_auth=user_auth)
#     129     if self.return_type is requests.Response:
#     130         return response
#
# File c:\Users\muham\anaconda3\envs\me\lib\site-packages\tweepy\client.py:95, in BaseClient.request(self, method, route, params, json, user_auth)
#      87 log.debug(
#      88     "Received API response: "
#      89     f"{response.status_code} {response.reason}\n"
#      90     f"Headers: {response.headers}\n"
#      91     f"Content: {response.content}"
#      92 )
#      94 if response.status_code == 400:
# ---> 95     raise BadRequest(response)
#      96 if response.status_code == 401:
#      97     raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# Your media IDs are invalid.

# %%
def autopostingAkunBackUp():
       
   API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
   API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
   BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
   ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
   SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

   auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
   auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
   API = twitter.API(auth)

   mycursor = mydb.cursor()

   mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup")

   accountResult = mycursor.fetchall()

   mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

   database_post = mycursor.fetchall()

   for i in range(len(accountResult)):
          
    random_index = random.randrange(len(database_post))

    urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
          
    media = API.media_upload("imagePost.png", additional_owners=[accountResult[i][1]])

    auth = twitter.OAuth1UserHandler(
        "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
        accountResult[i][3], accountResult[i][4]
    )
    api = twitter.API(auth)

    statusTweet = "‼ FLASH SALE ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3],accountResult[i][0] ))

    try:
        api.update_status(status=statusTweet, media_ids=[media.media_id])
        print(accountResult[i][2])
        print("✅ - Posting Berhasil\n")
    except:
        pass

def shortLinkShopee(link, idshopee):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link)
    res = res.replace("shope", "shpe")

    return(res)

autopostingAkunBackUp()
# Out:
# 1
# yusiedaynti
# ✅ - Posting Berhasil
#
# 1
# _firzaamanda
# ✅ - Posting Berhasil
#
# 1
# posyvidya77996
# ✅ - Posting Berhasil
#
# 1
# SimonJuarez282
# ✅ - Posting Berhasil
#
# 1
# samaira_nafisa
# ✅ - Posting Berhasil
#
# 1
# nirmalsalsabila
# ✅ - Posting Berhasil
#
# 1
# ArianaAbascal1
# ✅ - Posting Berhasil
#
# 1
# SaraAlamilla11
# ✅ - Posting Berhasil
#
# 1
# putridewia_a
# ✅ - Posting Berhasil
#
# 1
# vaniakeisya_
# ✅ - Posting Berhasil
#
# 2
# masitowae
# ✅ - Posting Berhasil

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup WHERE username <> 'zannakirana_' AND username <> 'vidyaisvara'")

accountResult = mycursor.fetchall()

for i in range(len(accountResult)):
    print(accountResult[i][2])
# Out:
# yusiedaynti
# _firzaamanda
# samaira_nafisa
# nirmalsalsabila
# ArianaAbascal1
# SaraAlamilla11
# putridewia_a
# vaniakeisya_
# masitowae
# imamto2003

# %%
def autopostingAkunBackUp():
    
   API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
   API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
   BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
   ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
   SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

   auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
   auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
   API = twitter.API(auth)

   mycursor = mydb.cursor()

   mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup WHERE id_shopee=2")

   accountResult = mycursor.fetchall()

   mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

   database_post = mycursor.fetchall()

   for i in range(len(accountResult)):
          
    random_index = random.randrange(len(database_post))

    urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
          
    media = API.media_upload("imagePost.png", additional_owners=[accountResult[i][1]])

    auth = twitter.OAuth1UserHandler(
        "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
        accountResult[i][3], accountResult[i][4]
    )
    api = twitter.API(auth)

    statusTweet = "‼ PROMO DISKON ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3],accountResult[i][0], accountResult[i][1] , "Twitter" ))

    try:
        api.update_status(status=statusTweet, media_ids=[media.media_id])
        print(accountResult[i][2])
        print("✅ - Posting Berhasil\n")
    except:
        pass

def shortLinkShopee(link, idshopee, akun, sosialmedia):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link, akun, sosialmedia)
    res = res.replace("shope", "shpe")
    return(res)

autopostingAkunBackUp()
# Out:
# masitowae
# ✅ - Posting Berhasil

# %%
import pandas as pd

id = "18il7-SVQ_kzEIszudzZBRCpM4uE8mK2nB6gT1jVXqLg"

komisiExtra = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{id}/export?format=csv")

komisiExtra
# Out:
#                                     product_name  product_price  \
# 0             Gamis dewasa, gamis lengan panjang           65.0
# 1       Daster semata kaki, daster lengan pendek           39.5
# 2                   Gamis kekinian, Gamis ceruty          110.0
# 3       Gamis dewasa, gamis kekinian,gamis murah           69.0
# 4  Daster, Daster lengan 3/4, Daster semata kaki           65.0
# 5                     Gamis kekinian,gamis murah           65.0
# 6                   Gamis ceruty, Gamis kekinian          110.0
# 7      Gamis kekinian, Gamis murah, gamis cantik           65.0
# 8                                  Daster kimono           57.5
# 9      Gamis ceruty Baby doll, gamis motif bunga          110.0
#
#   product_rating                                       product_link  \
# 0            70%  https://shopee.co.id/Gamis-dewasa-gamis-lengan...
# 1            75%  https://shopee.co.id/Daster-semata-kaki-daster...
# 2            65%  https://shopee.co.id/Gamis-kekinian-Gamis-ceru...
# 3            70%  https://shopee.co.id/Gamis-dewasa-gamis-kekini...
# 4            70%  https://shopee.co.id/Daster-Daster-lengan-3-4-...
# 5            75%  https://shopee.co.id/Gamis-kekinian-gamis-mura...
# 6            75%  https://shopee.co.id/Gamis-ceruty-Gamis-kekini...
# 7            55%  https://shopee.co.id/Gamis-kekinian-Gamis-mura...
# 8            65%  https://shopee.co.id/Daster-kimono-i.50829411....
# 9            70%  https://shopee.co.id/Gamis-ceruty-Baby-doll-ga...
#
#                                          product_img
# 0  https://cf.shopee.co.id/file/sg-11134201-22100...
# 1  https://cf.shopee.co.id/file/sg-11134201-22100...
# 2  https://cf.shopee.co.id/file/a9a99a4a2ff41ff8f...
# 3  https://cf.shopee.co.id/file/5bcbf60c5a4b9cacb...
# 4  https://cf.shopee.co.id/file/8510cb47fc4dab124...
# 5  https://cf.shopee.co.id/file/63f24ce846677482e...
# 6  https://cf.shopee.co.id/file/e5620a834781e1bb7...
# 7  https://cf.shopee.co.id/file/277791933e468e35e...
# 8  https://cf.shopee.co.id/file/1cb1102bdee442a84...
# 9  https://cf.shopee.co.id/file/a537dc05f18233376...

# %%
def autopostingBackup():
    print("\n\n🟧 AUTO POSTING : {}\n".format(datetime.now()))

    id = "18il7-SVQ_kzEIszudzZBRCpM4uE8mK2nB6gT1jVXqLg"

    komisiExtra = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{id}/export?format=csv")

    mycursor = mydb.cursor()

    mycursor.execute("SELECT username, API_KEY, API_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, SECRET_ACCESS_TOKEN FROM account_eleved")

    accountResult = mycursor.fetchall()

    for x in range(0, 1, 1):
        auth = twitter.OAuthHandler(accountResult[x][1], accountResult[x][2])
        auth.set_access_token(accountResult[x][4], accountResult[x][5])
        api = twitter.API(auth)

        profile = api.update_profile()

        print("\nAccount : {}".format(profile.name) + " ({})".format(profile.screen_name))

        random_index = random.randrange(len(komisiExtra))

        # upload image
        urllib.request.urlretrieve('{}'.format(komisiExtra.iloc[random_index, 4]), "imagePost.png")
        
        try:
            statusTweet = "‼ FLASH SALE ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(komisiExtra.iloc[random_index, 0], komisiExtra.iloc[random_index, 2], shortLinkShopee(komisiExtra.iloc[random_index][3], "1", "ExtraKomisi", "Twitter" ))
            media = api.media_upload("imagePost.png")
            api.update_status(status=statusTweet, media_ids=[media.media_id])
            print("✅ - Posting Berhasil\n")
        except:
            pass
       
def shortLinkShopee(link, idshopee, akun, sosialmedia):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link, akun, sosialmedia)
    res = res.replace("shope", "shpe")
    return(res)
    
autopostingBackup()
# Out:
# 🟧 AUTO POSTING : 2022-10-11 20:18:58.219014
#
#
# Account : My Fashion Collection✨ (id_myfashion)
# ✅ - Posting Berhasil

# %%
def autopostingTrendingTopik():
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    id = "1uEWUzNgy41bw5bczrP2yiziu7XSkJY0-HCs2VLYITrw"

    trendingTopik = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{id}/export?format=csv")

    trending = ""

    for i in range(len(trendingTopik)):
        trending += " " + trendingTopik.iloc[i,0]


    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)

    mycursor = mydb.cursor()

    mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup WHERE username='HappyRacun'")

    accountResult = mycursor.fetchall()

    mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

    database_post = mycursor.fetchall()

    for i in range(len(accountResult)):
            
        random_index = random.randrange(len(database_post))

        urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
            
        media = API.media_upload("imagePost.png", additional_owners=[accountResult[i][1]])

        auth = twitter.OAuth1UserHandler(
            "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
            accountResult[i][3], accountResult[i][4]
        )
        api = twitter.API(auth)

        statusTweet = "‼ PROMO DISKON ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}\n\ntag:{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3],accountResult[i][0], accountResult[i][1] , "Twitter" ), trending)
        
        print(statusTweet)
        try:
            api.update_status(status=statusTweet, media_ids=[media.media_id])
            print(accountResult[i][2])
            print("✅ - Posting Berhasil\n")
        except:
            pass
       
def shortLinkShopee(link, idshopee, akun, sosialmedia):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link, akun, sosialmedia)
    res = res.replace("shope", "shpe")
    return(res)
    
autopostingTrendingTopik()
# Out:
# [('2', '1585458215986548737', 'HappyRacun', '', '')]
# ‼ PROMO DISKON ‼
#
# Moofeat Chief - Sepatu Penny Loafers Pria Kulit Hitam
#
# ⛔️ DISKON : 17%
#
# Checkout Sekarang 👇
# https://shpe.ee/AtJR1e8sT
#
# tag: Nikita Mirzani BEM UI Jokowi Leslar

# %%
API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
API = twitter.API(auth)

# %%
trending = API.available_trends()

print(trending[3])

hasil = ""

for i in range(len(trending)):
    if(trending[i]['country'] == 'Indonesia'):
        print(trending[i])
# Out:
# {'name': 'Quebec', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/3444', 'parentid': 23424775, 'country': 'Canada', 'woeid': 3444, 'countryCode': 'CA'}
# {'name': 'Bekasi', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1030077', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1030077, 'countryCode': 'ID'}
# {'name': 'Depok', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1032539', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1032539, 'countryCode': 'ID'}
# {'name': 'Pekanbaru', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1040779', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1040779, 'countryCode': 'ID'}
# {'name': 'Surabaya', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1044316', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1044316, 'countryCode': 'ID'}
# {'name': 'Makassar', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1046138', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1046138, 'countryCode': 'ID'}
# {'name': 'Bandung', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1047180', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1047180, 'countryCode': 'ID'}
# {'name': 'Jakarta', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1047378', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1047378, 'countryCode': 'ID'}
# {'name': 'Medan', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1047908', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1047908, 'countryCode': 'ID'}
# {'name': 'Palembang', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1048059', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1048059, 'countryCode': 'ID'}
# {'name': 'Semarang', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1048324', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1048324, 'countryCode': 'ID'}
# {'name': 'Tangerang', 'placeType': {'code': 7, 'name': 'Town'}, 'url': 'http://where.yahooapis.com/v1/place/1048536', 'parentid': 23424846, 'country': 'Indonesia', 'woeid': 1048536, 'countryCode': 'ID'}
# {'name': 'Indonesia', 'placeType': {'code': 12, 'name': 'Country'}, 'url': 'http://where.yahooapis.com/v1/place/23424846', 'parentid': 1, 'country': 'Indonesia', 'woeid': 23424846, 'countryCode': 'ID'}

# %%
WOEID = 1047378

top_trends = API.get_place_trends(WOEID)

final = []

for i in range(len(top_trends[0]['trends'])):
    # if(top_trends[0]['trends'][i]['tweet_volume']):
        name = top_trends[0]['trends'][i]['name']
        volume = top_trends[0]['trends'][i]['tweet_volume']
        final.append([name,volume])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Bot\Bot Aff Shopee\test.ipynb Cell 26 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X35sZmlsZQ%3D%3D?line=13'>14</a> kata = []
#      <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X35sZmlsZQ%3D%3D?line=15'>16</a> for x in range(len(final)):
# ---> <a href='vscode-notebook-cell:/d%3A/Bot/Bot%20Aff%20Shopee/test.ipynb#X35sZmlsZQ%3D%3D?line=16'>17</a>     kata += " " + final[0]
#
# TypeError: can only concatenate str (not "list") to str

# %%
kata = ""

for x in range(10):
    random_index_trending = random.randrange(len(final))
    kata += " " + final[random_index_trending][0]

print(kata)
# Out:
#  Coleen Hasil Tes Otak Barcelona #HariBloggerNasional2022 #TesOtakKiriatauKanan Rihanna #TesOtakKiriatauKanan Tulus Utamakan Rakyat Barca Guling

# %%
def autopostingTrendingTopik():
    API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
    API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
    BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
    ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
    SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

    auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
    API = twitter.API(auth)

    #Scrap Trending ======================================================
    WOEID = 1047378

    top_trends = API.get_place_trends(WOEID)

    final = []

    for i in range(len(top_trends[0]['trends'])):
        # if(top_trends[0]['trends'][i]['tweet_volume']):
        name = top_trends[0]['trends'][i]['name']
        volume = top_trends[0]['trends'][i]['tweet_volume']
        final.append([name,volume])
    
    trending = ""

    # -===================================================================

    mycursor = mydb.cursor()

    mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup WHERE username='HappyRacun'")

    accountResult = mycursor.fetchall()

    mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

    database_post = mycursor.fetchall()

    for i in range(len(accountResult)):
            
        random_index = random.randrange(len(database_post))

        urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
            
        media = API.media_upload("imagePost.png", additional_owners=[accountResult[i][1]])

        auth = twitter.OAuth1UserHandler(
            "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
            accountResult[i][3], accountResult[i][4]
        )
        api = twitter.API(auth)

        for x in range(10):
            random_index_trending = random.randrange(len(final))
            trending += " " + final[random_index_trending][0]

        statusTweet = "‼ PROMO DISKON ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}\n\ntag:{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3],accountResult[i][0], accountResult[i][1] , "Twitter" ), trending)
        
        try:
            api.update_status(status=statusTweet, media_ids=[media.media_id])
            print(accountResult[i][2])
            print("✅ - Posting Berhasil\n")
        except:
            pass
       
def shortLinkShopee(link, idshopee, akun, sosialmedia):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link, akun, sosialmedia)
    res = res.replace("shope", "shpe")
    return(res)
    
autopostingTrendingTopik()
# Out:
# HappyRacun
# ✅ - Posting Berhasil

# %%
def autopostingAkunBackUp():
    
   API_KEY = "l8QEIHkBbb7Zpviv7ggt4XNpi"
   API_SECRET_KEY = "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N"
   BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAAFrcgEAAAAADBt2zOc80n%2B6VnrIFjKzMwfhP%2B4%3DexqN2RgSuElNEqmOgdH6vecjFDoX1XTYHOGvGqfHrvjE5vke37"
   ACCESS_TOKEN = "975213506696855553-UcOW4U41SPc5XgwylP1FnHeYLKbTR9N"
   SECRET_ACCESS_TOKEN = "kQM4qyISdaPrRBFOjb0zfRpUKMdmG7UBXpgrDNDrxQs5E"

   auth = twitter.OAuthHandler(API_KEY,  API_SECRET_KEY)
   auth.set_access_token(ACCESS_TOKEN, SECRET_ACCESS_TOKEN)
   API = twitter.API(auth)

   mycursor = mydb.cursor()

   mycursor.execute("SELECT id_shopee, id, username, access_token, access_token_secret FROM account_backup WHERE id_shopee = 3")

   accountResult = mycursor.fetchall()


   mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")

   database_post = mycursor.fetchall()

   for i in range(len(accountResult)):
          
    random_index = random.randrange(len(database_post))

    urllib.request.urlretrieve('{}'.format(database_post[random_index][4]), "imagePost.png")
          
    media = API.media_upload("imagePost.png", additional_owners=[accountResult[i][1]])

    auth = twitter.OAuth1UserHandler(
        "l8QEIHkBbb7Zpviv7ggt4XNpi", "eM4Id0y0DiTLT3TJNZ9MDxZOUlx1rt5njK012vdt7RTligP77N",
        accountResult[i][3], accountResult[i][4]
    )
    api = twitter.API(auth)

    statusTweet = "‼ PROMO DISKON ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3],accountResult[i][0], accountResult[i][1] , "Twitter" ))

    try:
        api.update_status(status=statusTweet, media_ids=[media.media_id])
        print(accountResult[i][2])
        print("✅ - Posting Berhasil\n")
    except:
        pass

def shortLinkShopee(link, idshopee, akun, sosialmedia):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link, akun, sosialmedia)
    res = res.replace("shope", "shpe")
    return(res)

autopostingAkunBackUp()
# Out:
# [('3', '1527930883462021120', 'LosSant0so', '1527930883462021120-htUuhI54ZcIpEAoEvsu8gCS2iquoT0', '5wWGernkcavLbX3d3TT9hHLC7veVyRGJZUjN91XySZHPQ')]
# LosSant0so
# ✅ - Posting Berhasil

# %%
import requests

def autoPostingFacebook():
    mycursor = mydb.cursor()
    mycursor.execute("SELECT product_name, product_price, product_rating, product_link, product_img FROM database_post")
    database_post = mycursor.fetchall()
    random_index = random.randrange(len(database_post))

    shopeid =1
    
    page_id= 105258409090407 
    facebook_access_token= 'EAAS1MRIVS4gBAFTx5PpZBtpFdm0TBLn60bBRq4EE4YR9fZB4ji6C9RZAiksiZBzp97001TrM1qUxvWMJ7WkibysHu6CCZBxyD0pWyaGyNuKMYYmn8TpzZAVPwD0VJeHkupoxZBAeHYiieXdexbd1KAkZCtHLZB082ME26y16CSVRKaQz8P2f5BMm0'
    statusTweet = "‼ PROMO DISKON ‼\n\n{}\n\n⛔️ DISKON : {}\n\nCheckout Sekarang 👇\n{}".format(database_post[random_index][0], database_post[random_index][2], shortLinkShopee(database_post[random_index][3],shopeid, "idmyfashion", "Facebook" ))
    # post_url = 'https://graph.facebook.com/{}/feed'.format(page_id_1)
    post_url = 'https://graph.facebook.com/v5.0/{}/photos'.format(page_id)
    imgUrl = database_post[random_index][4]

    payload = {
        'message': statusTweet,
        'access_token': facebook_access_token,
        'url': imgUrl
    }
    posting = requests.post(post_url, data=payload)
    print(posting)

def shortLinkShopee(link, idshopee, akun, sosialmedia):
    mycursor = mydb.cursor()
    mycursor.execute("SELECT id, appid, rahasia FROM account_shopeeaff WHERE id={}".format(idshopee))
    account_shopee = mycursor.fetchall()

    from shopee_affiliate import ShopeeAffiliate    
    sa = ShopeeAffiliate(account_shopee[0][1], account_shopee[0][2])
    res = sa.generateShortLink(link, akun, sosialmedia)
    res = res.replace("shope", "shpe")
    return(res)

autoPostingFacebook()
# Out:
# <Response [200]>
